# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pytdigest import TDigest
import numpy as np

# %%
digest = TDigest()

arr = np.random.random(1000)
print(arr)

digest.update(arr)
# Out:
# [2.95066967e-01 9.00351956e-01 9.25466962e-01 9.98158455e-01
#  6.14869913e-01 5.62921136e-01 3.10807024e-01 3.05840511e-01
#  5.35376715e-02 5.67074391e-01 9.79394052e-01 9.64883433e-01
#  3.84251230e-01 9.05619370e-01 1.76418273e-01 2.63973522e-01
#  8.09560858e-01 9.08981012e-01 8.97192034e-01 2.74618198e-01
#  2.84760230e-01 7.39402234e-01 8.17696801e-01 3.44607193e-01
#  2.35321891e-01 5.48207219e-01 2.19522676e-01 6.21126142e-01
#  4.25651373e-02 3.12687752e-01 5.71420622e-02 4.23737998e-01
#  1.56700016e-01 7.76502036e-01 1.14327411e-01 3.54841691e-01
#  9.99332415e-01 2.39738545e-01 5.67530610e-01 2.13705392e-01
#  9.59134969e-03 8.89824612e-01 9.90207444e-01 6.73914777e-01
#  7.72252339e-01 5.83777435e-01 6.21081170e-01 6.43549293e-01
#  1.12518465e-01 6.87109902e-01 8.98566944e-01 6.96903345e-01
#  8.11841982e-01 1.17813643e-01 6.70459373e-01 5.51771582e-01
#  8.51335184e-01 2.27781921e-01 9.35696565e-01 3.22445320e-01
# ...

# %%
inputs = np.random.random(10)

digest.cdf(inputs)
# Out:
# array([0.30661658, 0.36437133, 0.62053497, 0.21174293, 0.00942487,
#        0.19523701, 0.0160444 , 0.88143615, 0.92962543, 0.02683157])

# %%
centroids = digest.get_centroids()

# %%
TDigest.of_centroids(centroids)
# Out:
# TDigest(mean=0.493, weight=1e+03, centroids=42, merged, compression=100)
