# %%
import torch
import seaborn as sns


JITTER = 0.01

mask = torch.rand((50000)).lt(.99)

array = (torch.rand((50000)) - torch.rand((50000))) * JITTER * mask

# %%
sns.histplot(array.numpy())
# Out:
# <Axes: ylabel='Count'>
